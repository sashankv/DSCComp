# %%
import pandas as pd
from pathlib import Path

# %%
# Load the dataset as a pandas DataFrame
chr_analytic_df = pd.read_csv(Path.cwd() / "data" / "chr_analytic_data2022.csv", skiprows=1)

# %%
# Find correlation between columns
corr = chr_analytic_df.corr(method="pearson", numeric_only=True)
corr
# Out:
#                   statecode  countycode  fipscode  year  county_ranked  \
# statecode          1.000000    0.164398  0.999976   NaN      -0.006941
# countycode         0.164398    1.000000  0.171292   NaN      -0.012517
# fipscode           0.999976    0.171292  1.000000   NaN      -0.007022
# year                    NaN         NaN       NaN   NaN            NaN
# county_ranked     -0.006941   -0.012517 -0.007022   NaN       1.000000
# ...                     ...         ...       ...   ...            ...
# v058_rawvalue      0.013596   -0.071063  0.013074   NaN      -0.182232
# v058_numerator     0.001459   -0.107668  0.000691   NaN       0.148991
# v058_denominator  -0.029821   -0.089761 -0.030423   NaN       0.043083
# v058_cilow              NaN         NaN       NaN   NaN            NaN
# v058_cihigh             NaN         NaN       NaN   NaN            NaN
#
#                   v001_rawvalue  v001_numerator  v001_denominator  v001_cilow  \
# statecode             -0.061610       -0.040196         -0.040763   -0.068275
# countycode             0.086991       -0.035069         -0.035367    0.062290
# fipscode              -0.060922       -0.040397         -0.040965   -0.067754
# year                        NaN             NaN               NaN         NaN
# county_ranked               NaN             NaN               NaN         NaN
# ...                         ...             ...               ...         ...
# v058_rawvalue          0.239665       -0.061064         -0.064156   -0.006537
# v058_numerator        -0.043915        0.862065          0.793651    0.027595
# v058_denominator      -0.086701        0.983967          0.998386   -0.017042
# v058_cilow                  NaN             NaN               NaN         NaN
# v058_cihigh                 NaN             NaN               NaN         NaN
#
#                   v001_cihigh  ...  v057_rawvalue  v057_numerator  \
# statecode           -0.043465  ...      -0.007980       -0.040517
# countycode           0.095500  ...       0.026943       -0.035179
# fipscode            -0.042738  ...      -0.007779       -0.040718
# year                      NaN  ...            NaN             NaN
# county_ranked             NaN  ...       0.101481        0.043405
# ...                       ...  ...            ...             ...
# v058_rawvalue        0.433985  ...      -0.200306       -0.064358
# v058_numerator      -0.096699  ...       0.057899        0.797529
# v058_denominator    -0.131505  ...       0.062824        0.998371
# v058_cilow                NaN  ...            NaN             NaN
# v058_cihigh               NaN  ...            NaN             NaN
#
#                   v057_denominator  v057_cilow  v057_cihigh  v058_rawvalue  \
# statecode                -0.040507         NaN          NaN       0.013596
# countycode               -0.035176         NaN          NaN      -0.071063
# fipscode                 -0.040708         NaN          NaN       0.013074
# year                           NaN         NaN          NaN            NaN
# county_ranked             0.043472         NaN          NaN      -0.182232
# ...                            ...         ...          ...            ...
# v058_rawvalue            -0.064271         NaN          NaN       1.000000
# v058_numerator            0.795690         NaN          NaN      -0.125524
# v058_denominator          0.998257         NaN          NaN      -0.202429
# v058_cilow                     NaN         NaN          NaN            NaN
# v058_cihigh                    NaN         NaN          NaN            NaN
#
#                   v058_numerator  v058_denominator  v058_cilow  v058_cihigh
# statecode               0.001459         -0.029821         NaN          NaN
# countycode             -0.107668         -0.089761         NaN          NaN
# fipscode                0.000691         -0.030423         NaN          NaN
# year                         NaN               NaN         NaN          NaN
# county_ranked           0.148991          0.043083         NaN          NaN
# ...                          ...               ...         ...          ...
# v058_rawvalue          -0.125524         -0.202429         NaN          NaN
# v058_numerator          1.000000          0.796579         NaN          NaN
# v058_denominator        0.796579          1.000000         NaN          NaN
# v058_cilow                   NaN               NaN         NaN          NaN
# v058_cihigh                  NaN               NaN         NaN          NaN
#
# [723 rows x 723 columns]
